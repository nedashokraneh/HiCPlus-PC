# %%
import cooler
import numpy as np
from scipy import stats
import pandas as pd
import matplotlib.pyplot as plt

resolution = 10000

c = cooler.Cooler('/Users/neda/prostate-samples/PCa13266.multi-res.cool::/resolutions/10000')
total_num_reads = sum(c.pixels()[:,].iloc[:,2])
bin_names = c.bins()[:,]

# %%
def interaction_spurious_prob(chr_name1, region1, chr_name2, region2):
    first_bin_num = bin_names[bin_names.chrom == chr_name1].iloc[int(region1/resolution)].name
    second_bin_num = bin_names[bin_names.chrom == chr_name2].iloc[int(region2/resolution)].name
    region1_reads = np.sum(c.matrix(balance = False)[first_bin_num,])
    region2_reads = np.sum(c.matrix(balance = False)[second_bin_num,])
    ri = region1_reads / (2*total_num_reads)
    rj = region2_reads / (2*total_num_reads)
    random_prob = 2 * ri * rj
    num_int = c.matrix(balance = False)[first_bin_num, second_bin_num]
    rp = 1 - scipy.stats.binom.cdf(num_int, total_num_reads, random_prob)
    return (rp)
    
# *** if a region doesn't have any interaction so random_prob = 0 and rp = 0 but it doesn't show signigficant interaction

# %%
chr3_TADs = pd.read_csv("/Users/neda/prostate-samples/PCa13266.50000bp.chr3.domains.tsv", sep = "\t")
chr3_TADs = chr3_TADs[chr3_TADs.tag == "domain"]
down_bound = chr3_TADs.loc[chr3_TADs['size'].idxmax(),'from.coord']
up_bound = chr3_TADs.loc[chr3_TADs['size'].idxmax(),'to.coord']
peaks = pd.read_csv("/Users/neda/prostate-samples/PCa13266-ChipSeq/Pca13266_summits.bed", header = None, sep = "\t"
                   , names = ['chr_name', 'lower_bound', "upper_bound", "name", "enrichment"])
f_peaks = peaks[(peaks.chr_name == "chr3") & (peaks.lower_bound > down_bound) & (peaks.upper_bound < up_bound)]

# %%
down_bound_bin_num = bin_names[bin_names.chrom == "chr3"].iloc[int(down_bound/resolution)].name
up_bound_bin_num = bin_names[bin_names.chrom == "chr3"].iloc[int(up_bound/resolution)].name

# %%
bins_coverage = []
for i in range(down_bound_bin_num, up_bound_bin_num+1):
    bins_coverage.append(np.sum(c.matrix(balance = False)[i,]))

# %%
from scipy import stats
prob_mat = np.zeros([len(bins_coverage), len(bins_coverage)])
for (i_id, i) in enumerate(range(down_bound_bin_num, up_bound_bin_num + 1), 0):
    ri = bins_coverage[i_id] / (2*total_num_reads)
    for (j_id, j) in enumerate(range(i, up_bound_bin_num + 1), 0):
        rj = bins_coverage[j_id] / (2*total_num_reads)
        random_prob = 2 * ri * rj
        num_int = c.matrix(balance = False)[i,j]
        rp = 1 - scipy.stats.binom.cdf(num_int, total_num_reads, random_prob)
        prob_mat[i_id,j_id] = rp
# Out:
# ---------------------------------------------------------------------------
# NameError                                 Traceback (most recent call last)
# <ipython-input-29-487301f7e719> in <module>
#       7         random_prob = 2 * ri * rj
#       8         num_int = c.matrix(balance = False)[i,j]
# ----> 9         rp = 1 - scipy.stats.binom.cdf(num_int, total_num_reads, random_prob)
#      10         prob_mat[i_id,j_id] = rp
#
# NameError: name 'scipy' is not defined

# %%
plt.plot(bins_coverage)
plt.show()

# %%
background_random_probs = []
for fr in range(down_bound, up_bound, 10000):
    for sr in range(fr, up_bound, 10000):
        background_random_probs.append(interaction_spurious_prob("chr3", fr, "chr3", sr))
        print("!")
# Out:
# !
# !
# ---------------------------------------------------------------------------
# KeyboardInterrupt                         Traceback (most recent call last)
# <ipython-input-133-fb584127aa3f> in <module>
#       2 for fr in range(down_bound, up_bound, 10000):
#       3     for sr in range(fr, up_bound, 10000):
# ----> 4         background_random_probs.append(interaction_spurious_prob("chr3", fr, "chr3", sr))
#       5         print("!")
#
# <ipython-input-132-dedb259dcd23> in interaction_spurious_prob(chr_name1, region1, chr_name2, region2)
#      15     second_bin_num = bin_names[bin_names.chrom == chr_name2].iloc[int(region2/resolution)].name
#      16     region1_reads = np.sum(c.matrix(balance = False)[first_bin_num,])
# ---> 17     region2_reads = np.sum(c.matrix(balance = False)[second_bin_num,])
#      18     ri = region1_reads / (2*total_num_reads)
#      19     rj = region2_reads / (2*total_num_reads)
#
# ~/anaconda3/lib/python3.7/site-packages/cooler/core.py in __getitem__(self, key)
#     563         i0, i1 = self._process_slice(s1, self._shape[0])
#     564         j0, j1 = self._process_slice(s2, self._shape[1])
# --> 565         return self._slice(self.field, i0, i1, j0, j1)
#     566
#     567     def fetch(self, *args, **kwargs):
#
# ~/anaconda3/lib/python3.7/site-packages/cooler/api.py in _slice(field, i0, i1, j0, j1)
#     340                 return matrix(grp, i0, i1, j0, j1, field, balance, sparse,
#     341                     as_pixels, join, ignore_index, divisive_weights, max_chunk,
# --> 342                     self._is_symm_upper)
#     343
#     344         def _fetch(region, region2=None):
#
# ~/anaconda3/lib/python3.7/site-packages/cooler/api.py in matrix(h5, i0, i1, j0, j1, field, balance, sparse, as_pixels, join, ignore_index, divisive_weights, max_chunk, is_upper)
#     676         reader = CSRReader(h5, field, max_chunk)
#     677         if is_upper:
# --> 678             i, j, v = query_rect(reader.query, i0, i1, j0, j1, duplex=True)
#     679         else:
#     680             i, j, v = reader.query(i0, i1, j0, j1)
#
# ~/anaconda3/lib/python3.7/site-packages/cooler/core.py in query_rect(triu_reader, i0, i1, j0, j1, duplex)
#     401         # nested
#     402         elif _contains(i0, i1, j0, j1):
# --> 403             ix, jx, vx = triu_reader(i0, j0, j0, j1)
#     404             jy, iy, vy = triu_reader(j0, j1, j0, j1)
#     405             jz, iz, vz = triu_reader(j0, j1, j1, i1)
#
# ~/anaconda3/lib/python3.7/site-packages/cooler/core.py in query(self, i0, i1, j0, j1)
#     280                     cols = bin2[mask]
#     281
# --> 282                     i.append(np.full(len(cols), row_id, dtype=dtype))
#     283                     j.append(cols)
#     284                     v.append(all_data[lo:hi][mask])
#
# ~/anaconda3/lib/python3.7/site-packages/numpy/core/numeric.py in full(shape, fill_value, dtype, order)
#     334         dtype = array(fill_value).dtype
#     335     a = empty(shape, dtype, order)
# --> 336     multiarray.copyto(a, fill_value, casting='unsafe')
#     337     return a
#     338
#
# KeyboardInterrupt:

# %%
first_bin_num = bin_names[bin_names.chrom == chr_name1].iloc[int(region1/resolution)].name
    second_bin_num = bin_names[bin_names.chrom == chr_name2].iloc[int(region2/resolution)].name
    region1_reads = np.sum(c.matrix(balance = False)[first_bin_num,])
    region2_reads = np.sum(c.matrix(balance = False)[second_bin_num,])
    ri = region1_reads / (2*total_num_reads)
    rj = region2_reads / (2*total_num_reads)
    random_prob = 2 * ri * rj
    num_int = c.matrix(balance = False)[first_bin_num, second_bin_num]
    rp = 1 - scipy.stats.binom.cdf(num_int, total_num_reads, random_prob)
    return (rp)
# Out:
# chrom      chr1
# start         0
# end       10000
# weight      NaN
# Name: 0, dtype: object
